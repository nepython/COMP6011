# %% [markdown]
# ## 1. LLM generated diagnostics

# %%
import pandas as pd

stored_data_filename = 'Advanced Research Topics - Task 2.xlsx'

df = pd.read_excel(stored_data_filename, sheet_name='Generated prompts')
df.head(10)
# Out:
#                                               Prompt  \
# 0  Given the clinical case details, identify the ...
# 1  Given the clinical case details, identify the ...
# 2  Given the clinical case details, identify the ...
# 3  Given the clinical case details, identify the ...
# 4  Given the clinical case details, identify the ...
# 5  Given the clinical case details, identify the ...
# 6  Given the clinical case details, identify the ...
# 7  Given the clinical case details, identify the ...
# 8  Given the clinical case details, identify the ...
# 9  Given the clinical case details, identify the ...
#
#               Clinical diagnosis  \
# 0            Metastatic melanoma
# 1                  Not available
# 2                  Not available
# 3                  Not available
# 4                  Not available
# 5  Cutaneous bacterial infection
# 6                  Not available
# 7                  Not available
# 8                  Not available
# 9    Sarcoidosis or tuberculosis
#
#                                      Final Diagnosis  \
# 0                           Pulmonary histoplasmosis
# 1  Human immunodeficiency virus type 2 infection ...
# 2                       Borrelia miyamotoi infection
# 3                               Vitamin D deficiency
# 4                       Systemic primary amyloidosis
# 5             Erysipelothrix rhusiopathiae infection
# 6       Inflammatory bowel disease (Crohn’s disease)
# 7                               Aspiration pneumonia
# 8                   Granulomatosis with polyangiitis
# 9                                        Sarcoidosis
#
#                                      GPT-4o clinical  \
# 0                      Recurrent metastatic melanoma
# 1                              Cerebellar metastasis
# 2          Autoimmune encephalitis or CNS vasculitis
# 3  Hypocalcemia with seizure, possibly nutritiona...
# 4  Transient monocular vision loss, possible gian...
# 5                             Necrotizing fasciitis
# 6                                 Reactive arthritis
# 7                       Community‑acquired pneumonia
# 8                       Community‑acquired pneumonia
# 9                                            Uveitis
#
#                                         GPT-4o final  \
# 0                        Disseminated histoplasmosis
# 1                             Cerebral toxoplasmosis
# 2      Chronic Toxoplasma gondii meningoencephalitis
# 3    Nutritional rickets due to vitamin D deficiency
# 4  IgG4-related disease with orbital and hepatobi...
# 5        Group A Streptococcus necrotizing fasciitis
# 6                                    Crohn’s disease
# 7                   Invasive pulmonary aspergillosis
# 8          Anti‑glomerular basement membrane disease
# 9                                        Sarcoidosis
#
#                                      Gemini clinical  \
# 0                      Suspected metastatic melanoma
# 1                 Intracranial Mass Lesions and AIDS
# 2                                Meningoencephalitis
# 3                               Hypocalcemic Seizure
# 4   Suspected Giant Cell Arteritis with orbital mass
# 5                       Cellulitis with lymphangitis
# 6  Systemic inflammatory response with arthritis ...
# 7             Infectious Bronchiolitis and Pneumonia
# 8                           Pulmonary-renal syndrome
# 9                                Tuberculous uveitis
#
#                        Gemini final  \
# 0            Paracoccidioidomycosis
# 1               Can't be determined
# 2      Primary CNS Lymphoma (PCNSL)
# 3               Can't be determined
# 4              Systemic Sarcoidosis
# 5    Aeromonas hydrophila infection
# 6                  Crohn's disease.
# 7  Invasive Pulmonary Aspergillosis
# 8               Can't be determined
# 9               Can't be determined
#
#                                    DeepSeek clinical  \
# 0            Immune checkpoint inhibitor pneumonitis
# 1        Cerebellar mass lesion (suspected neoplasm)
# 2        Meningoencephalitis (autoimmune/infectious)
# 3  Hypocalcemic seizure secondary to suspected vi...
# 4                               Giant Cell Arteritis
# 5  Cellulitis with bullous formation and lymphang...
# 6                                       Lyme disease
# 7         Opportunistic fungal pneumonia (suspected)
# 8               Pulmonary-renal syndrome (suspected)
# 9           Uveitis (suspected tuberculous etiology)
#
#                                       Deepseek final  \
# 0               Immune-related sarcoid-like reaction
# 1                     CNS lymphoma (AIDS-associated)
# 2                                   Neurosarcoidosis
# 3  Vitamin D-dependent rickets (type likely confi...
# 4                               IgG4-Related Disease
# 5  Necrotizing cellulitis due to Streptococcus py...
# 6   Lyme arthritis with gastrointestinal involvement
# 7                   Invasive pulmonary aspergillosis
# 8  Anti-glomerular basement membrane (anti-GBM) d...
# 9                             Tuberculous Panuveitis
#
#                                        Grok clinical  \
# 0  Recurrent metastatic melanoma with pulmonary i...
# 1     Cerebellar tumor, possible metastatic disease.
# 2   Encephalitis, possible autoimmune or infectious.
# 3                               Hypocalcemic seizure
# 4                     Suspected giant cell arteritis
# 5                                         Cellulitis
# 6                         Inflammatory Bowel Disease
# 7                                          Pneumonia
# 8       Pneumonia with suspected glomerulonephritis.
# 9                                            Uveitis
#
#                                           Grok final  \
# 0  Metastatic melanoma with BRAF V600E mutation, ...
# 1     Cerebellar tumor, possible metastatic disease.
# 2           Primary central nervous system lymphoma.
# 3                       Vitamin D deficiency rickets
# 4                               Metastatic carcinoma
# 5                           Streptococcal cellulitis
# 6                                    Crohn’s Disease
# 7                   Invasive Pulmonary Aspergillosis
# 8  Pulmonary-renal syndrome (suspected Goodpastur...
# 9                                        Sarcoidosis
#
#                                     o4-mini clinical  \
# 0                      Pulmonary metastatic melanoma
# 1  Metastatic cerebellar neoplasm (brain metastas...
# 2            Aseptic lymphocytic meningoencephalitis
# 3          Hypocalcemic seizure (suspected rickets)
# 4                    Giant cell (temporal) arteritis
# 5                              Necrotizing fasciitis
# 6                             Suspected Lyme disease
# 7   Recurrent pneumonia in an immunocompromised host
# 8                       Community‑acquired pneumonia
# 9           Bilateral granulomatous anterior uveitis
#
#                                        o4-mini final
# 0  Pembrolizumab‑induced sarcoid‑like granulomato...
# 1       HIV‑associated diffuse large B‑cell lymphoma
# 2  Primary CNS lymphoma (vitreoretinal large B‑ce...
# 3           Nutritional vitamin D–deficiency rickets
# 4          IgG4‑related orbital inflammatory disease
# 5        Group A Streptococcus necrotizing fasciitis
# 6                                    Crohn’s disease
# 7          Subacute invasive pulmonary aspergillosis
# 8                    Anti‑GBM (Goodpasture) syndrome
# 9                   Sarcoidosis (ocular sarcoidosis)

# %% [markdown]
# ## 2. BLEU, ROUGE, Semantic similarity evaluation

# %%
# !pip install -q torchmetrics transformers pandas nltk rouge-score
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for rouge-score (setup.py) ... done

# %%
import pandas as pd
import warnings
from torchmetrics.text import BERTScore
from transformers import AutoTokenizer, AutoModel
from nltk.translate.bleu_score import sentence_bleu
from rouge_score import rouge_scorer

warnings.filterwarnings("ignore")

def calculate_metrics(df, column_dict, bert_base_model_name='bert-base-uncased', clinical_bert_base_model_name = "emilyalsentzer/Bio_ClinicalBERT"):
    # Initialize BERTScore
    model = AutoModel.from_pretrained(bert_base_model_name)
    clinical_model = AutoModel.from_pretrained(clinical_bert_base_model_name)
    bertscore = BERTScore(model_name_or_path=bert_base_model_name, num_layers=9)
    clinicalbertscore = BERTScore(model_name_or_path=clinical_bert_base_model_name, num_layers=9)

    # Initialize ROUGE scorer
    rouge = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)

    # Prepare results dictionary
    results = {metric: {} for metric in ['BLEU', 'ROUGE-L', 'BERTScore', 'ClinicalBERTScore']}

    for cand_col, ref_col in column_dict.items():
        references = df[ref_col].tolist()
        candidates = df[cand_col].tolist()

        # Calculate BLEU scores
        bleu_scores = [sentence_bleu([ref.split()], cand.split()) for ref, cand in zip(references, candidates)]
        results['BLEU'][cand_col] = round(sum(bleu_scores) / len(bleu_scores), 3)

        # Calculate ROUGE-L scores
        rouge_scores = [rouge.score(ref, cand)['rougeL'].fmeasure for ref, cand in zip(references, candidates)]
        results['ROUGE-L'][cand_col] = round(sum(rouge_scores) / len(rouge_scores), 3)

        # Calculate BERTScore
        bert_scores = bertscore(references, candidates)
        results['BERTScore'][cand_col] = round(bert_scores['f1'].mean().item(), 3)

        # Calculate ClinicalBERTScore
        clinical_bert_scores = clinicalbertscore(references, candidates)
        results['ClinicalBERTScore'][cand_col] = round(clinical_bert_scores['f1'].mean().item(), 3)

    # Convert results to DataFrame
    results_df = pd.DataFrame(results)
    return results_df

column_dict = {
    'GPT-4o final': 'Final Diagnosis',
    'Gemini final': 'Final Diagnosis',
    'Deepseek final': 'Final Diagnosis',
    'Grok final': 'Final Diagnosis',
    'o4-mini final': 'Final Diagnosis',
}

results_df = calculate_metrics(df, column_dict)
results_df
# Out:
#                 BLEU  ROUGE-L  BERTScore  ClinicalBERTScore
# GPT-4o final     0.0    0.313      0.454              0.645
# Gemini final     0.0    0.140      0.391              0.619
# Deepseek final   0.0    0.033      0.446              0.647
# Grok final       0.0    0.271      0.450              0.636
# o4-mini final    0.0    0.192      0.410              0.636

# %% [markdown]
# ## 3. LLM based evaluation
# This was performed using three models: Qwen 2.5 Max, Llama 4 Maverick, Claude 3.7 Sonnet

# %%
llm_df = pd.read_excel(stored_data_filename, sheet_name='Accuracy Judgement')
llm_df.tail(6)
# Out:
#                                              Column 1  \
# 12                             Qwen 2.5 Max judgement
# 13                                   Claude judgement
# 14                                    Llama judgement
# 15              Majority voting by the above 3 models
# 16  Majority voting by similar architectures (GPT4...
# 17                              Mean score of the two
#
#              GPT-4o sub prompt   Gemini-Pro-2.5 sub prompt  \
# 12  b b c b c c a c c a (35.0)  c b c c c c a c c c (15.0)
# 13  b c c b c c a c c a (30.0)  c c c c c c a c c c (10.0)
# 14  b c c b c c a c c a (30.0)  c b c c c c a c c c (15.0)
# 15  b c c b c c a c c a (30.0)  c b c c c c a c c c (15.0)
# 16  b b c a c c a c c a (40.0)  c b c b c c a c b c (25.0)
# 17                          35                          20
#
#         Deekseek-R1 sub prompt            Grok3 sub prompt  \
# 12  c b c b c c c c c c (10.0)  c c c a c c a c c a (30.0)
# 13   c c c b c c c c c c (5.0)  c c c b c c a c c a (25.0)
# 14  c b c b c c c c b c (15.0)  c a b b c c a c b a (45.0)
# 15  c b c b c c c c c c (10.0)  c c c b c c a c c a (25.0)
# 16   c b c c c c c c c c (5.0)  c c b b c c a b b b (35.0)
# 17                         7.5                          30
#
#             o4-mini sub prompt  \
# 12  c b c a c c a c c a (35.0)
# 13  c c c b c c a c c a (25.0)
# 14  c c c b c c a c c a (25.0)
# 15  c c c b c c a c c a (25.0)
# 16  c c c b c c a c c a (25.0)
# 17                          25
#
#                                            Unnamed: 6
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16  Microsoft copilot is said to use Prometheus mo...
# 17                                                NaN

# %% [markdown]
# ## 4. Chain of thoughts generated

# %%
import os

thoughts_dir = 'Chain of Thoughts'

# Number of models
[directory for directory in os.listdir(thoughts_dir) if not directory.startswith('.')]
# Out:
# ['GPT-4o', 'o4-mini', 'Gemini 2.5 Pro', 'Deepseek R1', 'Grok 3']

# %%
# Cases present
# !ls -R Chain\ of\ Thoughts
# Out:
# 'Chain of Thoughts':
# 'Deepseek R1'  'Gemini 2.5 Pro'   GPT-4o  'Grok 3'   o4-mini
#
# 'Chain of Thoughts/Deepseek R1':
# case10.txt  case2.txt  case4.txt  case6.txt  case8.txt
# case1.txt   case3.txt  case5.txt  case7.txt  case9.txt
#
# 'Chain of Thoughts/Gemini 2.5 Pro':
# case10.txt  case2.txt  case4.txt  case6.txt  case8.txt
# case1.txt   case3.txt  case5.txt  case7.txt  case9.txt
#
# 'Chain of Thoughts/GPT-4o':
# case10.txt  case2.txt  case4.txt  case6.txt  case8.txt
# case1.txt   case3.txt  case5.txt  case7.txt  case9.txt
#
# 'Chain of Thoughts/Grok 3':
# case10.txt  case2.txt  case4.txt  case6.txt  case8.txt
# case1.txt   case3.txt  case5.txt  case7.txt  case9.txt
#
# 'Chain of Thoughts/o4-mini':
# case10.txt  case2.txt  case4.txt  case6.txt  case8.txt
# case1.txt   case3.txt  case5.txt  case7.txt  case9.txt
